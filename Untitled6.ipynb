# %%
import pandas as pd
import numpy as np
import re
import nltk
import spacy
import string

# %%
df = pd.read_csv('NLP_project_kickoff_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  ...                                             tokens
# 0           0  ...  ['White', 'human', 'face', 'person', 'smile', ...
# 1           1  ...  ['White', 'Grey', 'text', 'human', 'face', 'fa...
# 2           2  ...  ['White', 'skin', 'lip', 'closeup', 'eyelash',...
# 3           3  ...  ['White', 'Grey', 'text', 'screenshot', 'dog',...
# 4           4  ...  ['Brown', 'Black', 'Pink', 'undergarment', 'cl...
#
# [5 rows x 25 columns]

# %%
pip install emot
# Out:
# Collecting emot
#   Downloading emot-3.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 13 kB/s
# Installing collected packages: emot
# Successfully installed emot-3.1

# %%
from emot.emo_unicode import UNICODE_EMO
import emot

# Converting emojis to words
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
        return text



# Converting emoticons to words    
def convert_emoticons(text):
    for emot in EMOTICONS_EMO:
        text = re.sub(u'('+emot+')', "_".join(EMOTICONS_EMO[emot].replace(",","").split()), text)
        return text


# Example
text = "Hello :-) :-)"
convert_emoticons(text)
text1 = "Hilarious 😂"
convert_emojis(text1)


# Passing both functions to 'text_rare'
df['text_rare'] = df['text_rare'].apply(convert_emoticons)
df['text_rare'] = df['text_rare'].apply(convert_emojis)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-5f2dadcf92f6> in <module>()
# ----> 1 from emot.emo_unicode import UNICODE_EMO
#       2
#       3 # Converting emojis to words
#       4 def convert_emojis(text):
#       5     for emot in UNICODE_EMOJI:
#
# ImportError: cannot import name 'UNICODE_EMO' from 'emot.emo_unicode' (/usr/local/lib/python3.7/dist-packages/emot/emo_unicode.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
