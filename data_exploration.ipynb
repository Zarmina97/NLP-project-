# %%
# #To be run in further steps
# import gensim.downloader 
# import ast

# # Show all available models in gensim-data
# print(list(gensim.downloader.info()['models'].keys()))
# model = gensim.downloader.load('word2vec-google-news-300')

# %%
import pandas as pd
import numpy as np
import re
import nltk
import spacy
import string

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp gdrive/MyDrive/GitHub/NLP-project-/preprocessing_functions.py .

# %%
# !python preprocessing_functions.py

# %%
#df = pd.read_csv('NLP_project_kickoff_data.csv', encoding='utf-8')
df = pd.read_csv('NLP_project_kickoff_data.csv', encoding='utf-8')

# %%
df.head()
# Out:
#    Unnamed: 0  ...                          biography_wo_stopfreqrare
# 0           0  ...                                                nan
# 1           1  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 2           2  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 3           3  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 4           4  ...  ðÿœ� london, uk ðÿ�¥ co-founder @theplasticsur...
#
# [5 rows x 29 columns]

# %%
df_emo= pd.read_csv('emojis.csv')

# %% [markdown]
# ##Emoji replacement

# %%
for col in df.columns:
  #print(type(col))
  if type(col)=="<class 'str'>":
    emojis_replacement(col)  
  #  lower_column(col)

# %% [markdown]
# ##Text Lower

# %%
lower_column('biography')
lower_column('caption')
lower_column('tokens')

# %% [markdown]
# ##Remove punctuation

# %%
df.head()

# %%
df["biography_wo_punc"] = df["biography"].apply(lambda text: remove_punctuation(text))
#df["caption_wo_punc"] = df["caption"].apply(lambda text: remove_punctuation(text)) #not working
#df["profile_name"] = df["profile_name"].apply(lambda text: remove_punctuation(text)) #not working
#df["tokens_wo_punc"] = df["tokens"].apply(lambda text: remove_punctuation(text))


df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-5213d5ea0194> in <module>()
# ----> 1 df["biography_wo_punc"] = df["biography"].apply(lambda text: remove_punctuation(text))
#       2 #df["caption_wo_punc"] = df["caption"].apply(lambda text: remove_punctuation(text)) #not working
#       3 #df["profile_name"] = df["profile_name"].apply(lambda text: remove_punctuation(text)) #not working
#       4 #df["tokens_wo_punc"] = df["tokens"].apply(lambda text: remove_punctuation(text))
#       5
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-152-5213d5ea0194> in <lambda>(text)
# ----> 1 df["biography_wo_punc"] = df["biography"].apply(lambda text: remove_punctuation(text))
#       2 #df["caption_wo_punc"] = df["caption"].apply(lambda text: remove_punctuation(text)) #not working
#       3 #df["profile_name"] = df["profile_name"].apply(lambda text: remove_punctuation(text)) #not working
#       4 #df["tokens_wo_punc"] = df["tokens"].apply(lambda text: remove_punctuation(text))
#       5
#
# <ipython-input-32-eb7bd7ab01e6> in remove_punctuation(text)
#       2 def remove_punctuation(text):
#       3     """custom function to remove the punctuation"""
# ----> 4     return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))
#       5
#       6 df["biography_wo_punc"] = df["biography"].apply(lambda text: remove_punctuation(text))
#
# AttributeError: 'float' object has no attribute 'translate'

# %%
pip install --upgrade nltk

# %%
pip install  --upgrade gensim --pre

# %%
# !pip install --upgrade gensim

# %%
import nltk
nltk.download('stopwords')

# %%
df["biography_wo_stop"] = df["biography"].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
#    Unnamed: 0  ...                                  biography_wo_stop
# 0           0  ...                                                nan
# 1           1  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 2           2  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 3           3  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 4           4  ...  ðÿœ� london, uk ðÿ�¥ co-founder @theplasticsur...
#
# [5 rows x 27 columns]

# %% [markdown]
# #Removal of frequent words

# %%
from collections import Counter
cnt = Counter()
for text in df["biography_wo_stop"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)
# Out:
# [('&', 166),
#  ('based', 128),
#  ('home', 112),
#  ('enhancing', 104),
#  ('ð�—¡ð�—®ð�˜�ð�˜‚ð�—¿ð�—®ð�—¹', 104),
#  ('ð�—•ð�—²ð�—®ð�˜‚ð�˜�ð�˜†', 104),
#  ('ðÿœ¥', 104),
#  ('@officialnavyprofessional', 104),
#  ('educator-', 104),
#  ('discount', 104)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
# def remove_freqwords(text):
#     """custom function to remove the frequent words"""
#     return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["biography_wo_stopfreq"] = df["biography_wo_stop"].apply(lambda text: remove_freqwords(text))
df.head()
# Out:
#    Unnamed: 0  ...                              biography_wo_stopfreq
# 0           0  ...                                                nan
# 1           1  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 2           2  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 3           3  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 4           4  ...  ðÿœ� london, uk ðÿ�¥ co-founder @theplasticsur...
#
# [5 rows x 28 columns]

# %% [markdown]
# #removal of rare words

# %%
n_rare_words = 10
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])

# %%
df["biography_wo_stopfreqrare"] = df["biography_wo_stopfreq"].apply(lambda text: remove_rarewords(text))
df.head()
# Out:
#    Unnamed: 0  ...                          biography_wo_stopfreqrare
# 0           0  ...                                                nan
# 1           1  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 2           2  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 3           3  ...  facial cosmetics, ent thyroid clinic mr. mrina...
# 4           4  ...  ðÿœ� london, uk ðÿ�¥ co-founder @theplasticsur...
#
# [5 rows x 29 columns]

# %% [markdown]
# #Stemming

# %%
# from nltk.stem.porter import PorterStemmer

# stemmer = PorterStemmer()
# def stem_words(text):
#     return " ".join([stemmer.stem(word) for word in text.split()])

# %%
df["biography_stemmed"] = df["biography_wo_punc"].apply(lambda text: stem_words(text))
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'biography_wo_punc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-161-1ef0f36f7063> in <module>()
# ----> 1 df["biography_stemmed"] = df["biography_wo_punc"].apply(lambda text: stem_words(text))
#       2 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'biography_wo_punc'

# %%
from nltk.stem.snowball import SnowballStemmer
SnowballStemmer.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %% [markdown]
# #Lemmatization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer

# lemmatizer = WordNetLemmatizer()
# def lemmatize_words(text):
#     return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

df["biography_lemm"] = df["biography_stemmed"].apply(lambda text: lemmatize_words(text))
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'biography_stemmed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-fc48d418be51> in <module>()
#       5 #     return " ".join([lemmatizer.lemmatize(word) for word in text.split()])
#       6
# ----> 7 df["biography_lemm"] = df["biography_stemmed"].apply(lambda text: lemmatize_words(text))
#       8 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'biography_stemmed'

# %% [markdown]
# #Removal of URLs

# %%
df['biography_wo_urls']=df['biography_lemm'].apply(remove_urls)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'biography_lemm'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-c45ace16c14d> in <module>()
# ----> 1 df['biography_wo_urls']=df['biography_lemm'].apply(remove_urls)
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'biography_lemm'

# %% [markdown]
# #Removal of HTML tags

# %%
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

print(remove_html(text))
# Out:
# Lcomputer Liphone Lmusic8 Lgame2 âš½â˜•ðŸ»ðŸ•
