# %%
import pandas as pd
#df_cosmetics=pd.read_csv('df_cosmetics.csv')
df_hospitality=pd.read_csv('df_hospitality.csv')

# %%
df_hospitality.shape #I used the half of the rows
# Out:
# (36721, 24)

# %% [markdown]
# #Clustering df_hospitality

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# initialize the vectorizer
vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=5, max_df=0.95)
# fit_transform applies TF-IDF to clean texts - we save the array of vectors in X
X = vectorizer.fit_transform(df_hospitality['caption'].astype(str))

# %%
df_hospitality['SUB-CATEGORY'].unique() #27
# Out:
# array(['restaurant', 'hotel', 'pub', 'doughnut shop', 'bakery', 'café',
#        'bar & grill', 'bar & kitchen', 'breakfast & brunch restaurant',
#        'streetfood market', 'bar', 'pastry shop', 'chocolate shop',
#        'brewery', 'wine bar & shop', 'coffee / food shop', 'cocktail bar',
#        'ice cream shop', 'serviced apartments', 'pub & restaurant',
#        'fast food chain', 'empanadas store / delivery', 'wine bar',
#        'dessert shop',
#        'restaurants / lifestyle shop / deli / plant nursery', nan],
#       dtype=object)

# %%
from sklearn.cluster import KMeans

# initialize kmeans with 3 centroids
kmeans = KMeans(n_clusters=27, random_state=42)
# fit the model
kmeans.fit(X)
# store cluster labels in a variable
clusters = kmeans.labels_

# %%
from sklearn.decomposition import PCA

# initialize PCA with 2 components
pca = PCA(n_components=2, random_state=42)
# pass our X to the pca and store the reduced vectors into pca_vecs
pca_vecs = pca.fit_transform(X.toarray())
# save our two dimensions into x0 and x1
x0 = pca_vecs[:, 0]
x1 = pca_vecs[:, 1]

# %%
df_hospitality['cluster'] = clusters
df_hospitality['x0'] = x0
df_hospitality['x1'] = x1

cluster_map_hospitality = {0: 'restaurant', 1:'hotel', 2:'pub', 3:'doughnut shop', 4:'bakery', 5:'café',
       6:'bar & grill', 7:'bar & kitchen', 8:'breakfast & brunch restaurant',
       9:'streetfood market', 10:'bar', 11:'pastry shop', 12:'chocolate shop',
       13:'brewery', 14:'wine bar & shop', 15:'coffee / food shop', 16:'cocktail bar',
       17:'ice cream shop', 18:'serviced apartments', 19:'pub & restaurant',
       20:'fast food chain', 21:'empanadas store / delivery', 22:'wine bar',
       23:'dessert shop',
       24:'restaurants / lifestyle shop / deli / plant nursery',
       25:'food delivery', 26: 'beer garden'} # mapping found through get_top_keywords
df_hospitality['cluster'] = df_hospitality['cluster'].map(cluster_map_hospitality);

# %%
import numpy as np
def get_top_keywords(n_terms, df):
    """This function returns the keywords for each centroid of the KMeans"""
    df = pd.DataFrame(X.todense()).groupby(clusters).mean() # groups the TF-IDF vector by cluster
    terms = vectorizer.get_feature_names_out() # access tf-idf terms
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([terms[t] for t in np.argsort(r)[-n_terms:]])) # for each row of the dataframe, find the n terms that have the highest tf idf score
      
get_top_keywords(20, df_hospitality)
# Out:
# Cluster 0
# like,delicious,get,summer,ready,cake,what,london,favourite,who,time,morning,new,good,today,week,us,one,our,it
#
# Cluster 1
# next,website,head,gift,new,enjoy,our,find,available,click,menu,the,us,we,th,table,via,book,link,bio
#
# Cluster 2
# christmas,favourite,date,time,it,lover,bombe,ing,would,unch,cocktail,did,say,share,needs,loves,who,love,someone,tag
#
# Cluster 3
# we,prize,friend,us,cs,announced,luck,share,th,like,giveaway,follow,to,post,chance,enter,competition,tag,winner,win
#
# Cluster 4
# get,know,open,welcome,soon,love,week,it,got,can,wait,new,see,ll,you,us,back,ve,re,we
#
# Cluster 5
# delicious,today,available,strawberries,caramel,our,dessert,topped,jam,filled,whipped,cake,raspberry,fresh,sponge,strawberry,vanilla,chocolate,ice,cream
#
# Cluster 6
# cake,today,free,shop,website,our,get,we,via,click,pre,collect,collection,online,home,bio,link,available,delivery,order
#
# Cluster 7
# open,pepes,pm,orders,vouchers,gift,via,fisherslondon,we,book,delivery,deliveroo,collection,available,steakhouse,https,tomahawk,www,uk,co
#
# Cluster 8
# roasted,our,red,pickled,smoked,beef,tomato,crispy,salad,garlic,onion,fried,new,served,vegan,chilli,menu,sauce,cheese,chicken
#
# Cluster 9
# pastries,monday,week,sunday,morning,till,back,day,saturday,come,us,see,coffee,tomorrow,re,today,we,am,open,pm
#
# Cluster 10
# finish,finished,finishes,finishing,finlayson,fior,fir,first,fire,firepit,fireplace,fires,fireside,firework,fireworks,firing,firm,fired,𝟐𝟓,nan
#
# Cluster 11
# our,it,first,queen,today,back,bar,time,week,team,new,room,hotel,us,we,one,london,best,perfect,the
#
# Cluster 12
# who,ready,day,unch,bio,happy,coffee,link,enjoy,hope,book,pm,us,re,open,we,monday,weekend,holiday,bank
#
# Cluster 13
# every,tried,favourite,life,we,king,why,instead,there,know,try,support,something,offer,see,show,what,check,account,whopper
#
# Cluster 14
# open,mince,time,get,season,available,it,our,th,day,the,gift,us,year,eve,december,we,merry,festive,christmas
#
# Cluster 15
# edition,who,we,menu,ivy,onwards,delicious,pm,enjoy,dining,us,clicking,may,please,to,link,bio,make,click,reservation
#
# Cluster 16
# perfect,delicious,ending,available,saturday,easy,unch,today,lunch,pm,gaucho,like,roasts,we,us,book,day,morning,roast,sunday
#
# Cluster 17
# afternoon,table,last,tingthai,caravan,tattulondon,atpizza,the,order,minute,book,availability,doefoods,thepolizzicollection,menu,bookings,hotelendsleigh,seriverhouse,www,com
#
# Cluster 18
# delicious,link,bio,available,this,image,notes,enjoy,us,week,one,today,day,get,it,morning,the,we,cup,coffee
#
# Cluster 19
# day,huge,re,guests,back,customers,the,wonderful,last,love,it,amazing,much,year,team,support,everyone,us,we,thank
#
# Cluster 20
# have,get,special,treats,plans,cheers,what,come,friday,cocktails,start,it,joining,the,ready,unch,we,who,us,weekend
#
# Cluster 21
# made,new,our,cream,topped,one,raspberry,we,available,cookie,today,milk,orange,hazelnut,cake,dark,caramel,hot,white,chocolate
#
# Cluster 22
# full,us,please,if,send,com,experience,work,part,time,re,co,uk,hiring,email,we,cv,looking,join,team
#
# Cluster 23
# make,treat,like,national,get,celeate,available,the,start,one,mother,every,us,love,we,it,happy,today,valentine,day
#
# Cluster 24
# summer,evening,flowers,morning,new,richmond,park,one,photo,today,perfect,week,our,it,us,day,the,wedding,we,beautiful
#
# Cluster 25
# caramel,today,cocktail,share,fave,day,the,first,chocolate,dish,meet,we,ivy,memory,comment,one,favourite,choose,would,which
#
# Cluster 26
# today,soon,hope,back,friends,the,team,easter,valentine,us,guests,friday,birthday,we,everyone,day,new,wishing,year,happy

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# set image size
plt.figure(figsize=(20, 10))
# set title
plt.title("Grouping TF-IDF + KMeans ", fontdict={"fontsize": 18})
# set axes names
plt.xlabel("X0", fontdict={"fontsize": 16})
plt.ylabel("X1", fontdict={"fontsize": 16})
#  create scatter plot with seaborn, where hue is the class used to group the data
sns.scatterplot(data=df_hospitality, x='x0', y='x1', hue='cluster', palette="bright")
plt.savefig('hospitality_clustering.png')

plt.show()
