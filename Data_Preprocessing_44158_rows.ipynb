# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp gdrive/MyDrive/GitHub/NLP-project-/preprocessing_functions.py .

# %%
import pandas as pd
import numpy as np
import re
import nltk
import spacy
import string
import preprocessing_functions
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
# !python preprocessing_functions.py
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
execfile('preprocessing_functions.py')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# #Text pre-processing

# %%
#df = pd.read_csv('NLP_project_kickoff_data.csv', encoding='utf-8')
#df = pd.read_csv('Instagram.csv', encoding='utf-8')
df=pd.read_csv('Instagram_profile_20220220_172954.success.csv', encoding='utf-8', sep=',')
df

#df_emo= pd.read_csv('emojis.csv')
# Out:
#                 account                                            caption  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 44154  drdariushnikkhah  Finalising the 50 chapters of an exciting book...
# 44155  drdariushnikkhah  At Harefield heart ❤️ hospital - probably only...
# 44156  drdariushnikkhah  Great to be back at the first face to face sci...
# 44157  drdariushnikkhah  Before and after of a bilateral breast reducti...
# 44158  drdariushnikkhah  Local anaesthetic flexor tendon repair is a sa...
#
#                          profile_name  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 44154  Mr Dariush Nikkhah FRCS(Plast)
# 44155  Mr Dariush Nikkhah FRCS(Plast)
# 44156  Mr Dariush Nikkhah FRCS(Plast)
# 44157  Mr Dariush Nikkhah FRCS(Plast)
# 44158  Mr Dariush Nikkhah FRCS(Plast)
#
#                                       profile_image_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44155  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44156  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44157  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44158  https://scontent-lhr8-1.cdninstagram.com/v/t51...
#
#                                                biography            id  \
# 0                                                    NaN           NaN
# 1      🌎🧳🔥🥇🎨🍷☕\n          🇻🇪  🇨🇴\nEMPRESARIO SOÑADOR\...  3.654414e+09
# 2                                                    NaN           NaN
# 3          Consultant Plastic and Reconstructive Surgeon  1.366797e+09
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44154  Consultant Plastic Surgeon\n▪️London, U.K. \n📩...  2.648973e+18
# 44155  Consultant Plastic Surgeon\n▪️London, U.K. \n📩...  2.647971e+18
# 44156  Consultant Plastic Surgeon\n▪️London, U.K. \n📩...  2.659552e+18
# 44157  Consultant Plastic Surgeon\n▪️London, U.K. \n📩...  2.646593e+18
# 44158                                                NaN           NaN
#
#        business_email                         external_url  following  likes  \
# 0                 NaN                                  NaN        NaN    NaN
# 1                 NaN                                  NaN     1105.0    NaN
# 2                 NaN                                  NaN        NaN    NaN
# 3                 NaN                http://www.psauk.org/       57.0    NaN
# 4                 NaN                                  NaN        NaN    NaN
# ...               ...                                  ...        ...    ...
# 44154             NaN  https://www.plasticreconsurg.co.uk/      299.0  137.0
# 44155             NaN  https://www.plasticreconsurg.co.uk/      299.0   83.0
# 44156             NaN  https://www.plasticreconsurg.co.uk/      299.0   75.0
# 44157             NaN  https://www.plasticreconsurg.co.uk/      299.0   77.0
# 44158             NaN                                  NaN        NaN    NaN
#
#       media_type  posts_count  followers  is_verified      datetime  \
# 0            NaN          NaN        NaN          NaN           NaN
# 1            NaN        515.0     1244.0          NaN           NaN
# 2            NaN          NaN        NaN          NaN           NaN
# 3            NaN          8.0       13.0          NaN           NaN
# 4            NaN          NaN        NaN          NaN           NaN
# ...          ...          ...        ...          ...           ...
# 44154      Image        136.0     1124.0          NaN  1.630002e+12
# 44155      Image        136.0     1124.0          NaN  1.629883e+12
# 44156   Carousel        136.0     1124.0          NaN  1.631263e+12
# 44157      Image        136.0     1124.0          NaN  1.629718e+12
# 44158        NaN          NaN        NaN          NaN           NaN
#
#                                                image_url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44155  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44156  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44157  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44158                                                NaN
#
#                                             url  comments  \
# 0                                           NaN       NaN
# 1                                           NaN       NaN
# 2                                           NaN       NaN
# 3                                           NaN       NaN
# 4                                           NaN       NaN
# ...                                         ...       ...
# 44154  https://www.instagram.com/p/CTDCnYcqSBP/       6.0
# 44155  https://www.instagram.com/p/CS_e1ntq-Qo/       3.0
# 44156  https://www.instagram.com/p/CTooI4TK0sF/       0.0
# 44157  https://www.instagram.com/p/CS6lisWKX4k/       7.0
# 44158                                       NaN       NaN
#
#                                               thumbnails  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44155  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44156  [{"src":"https://scontent-lhr8-1.cdninstagram....
# 44157  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44158                                                NaN
#
#                      location
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 44154  London, United Kingdom
# 44155                     NaN
# 44156     Oxford, Oxfordshire
# 44157  London, United Kingdom
# 44158                     NaN
#
# [44159 rows x 20 columns]

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,'percent_missing': percent_missing})
missing_value_df
# Out:
#                            column_name  percent_missing
# account                        account         0.092846
# caption                        caption         0.695215
# profile_name              profile_name         0.267216
# profile_image_link  profile_image_link         0.092846
# biography                    biography         0.799384
# id                                  id         0.036233
# business_email          business_email       100.000000
# external_url              external_url         3.172626
# following                    following         0.036233
# likes                            likes         0.095111
# media_type                  media_type         0.095111
# posts_count                posts_count         0.036233
# followers                    followers         0.036233
# is_verified                is_verified        86.863380
# datetime                      datetime         0.095111
# image_url                    image_url         0.095111
# url                                url         0.095111
# comments                      comments         0.095111
# thumbnails                  thumbnails         0.095111
# location                      location        50.533300

# %%
df.dtypes
# Out:
# account                object
# caption                object
# profile_name           object
# profile_image_link     object
# biography              object
# id                    float64
# business_email        float64
# external_url           object
# following             float64
# likes                 float64
# media_type             object
# posts_count           float64
# followers             float64
# is_verified           float64
# datetime              float64
# image_url              object
# url                    object
# comments              float64
# thumbnails             object
# location               object
# dtype: object

# %%
string_columns=['biography', 'caption']

# %%
df.shape
# Out:
# (44159, 20)

# %% [markdown]
# ##Emoji replacement

# %%
#To be run for other instagram datasets 
# for i in string_columns:
#   emojis_replacement(df[i])

# %%
pip install emot
# Out:
# Collecting emot
#   Downloading emot-3.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 15 kB/s
# Installing collected packages: emot
# Successfully installed emot-3.1

# %%
import re
import pickle
#from emot.emo_unicode import UNICODE_EMO, EMOTICONS
from emot.emo_unicode import UNICODE_EMOJI # For emojis
from emot.emo_unicode import EMOTICONS_EMO # For EMOTICONS

with open('Emoji_Dict.p', 'rb') as fp:
    Emoji_Dict = pickle.load(fp)
Emoji_Dict = {v: k for k, v in Emoji_Dict.items()}

def convert_emojis_to_word(text):
    for emot in Emoji_Dict:
        text = re.sub(r'('+emot+')', "_".join(Emoji_Dict[emot].replace(",","").replace(":","").split()), text)
    return text

#text = "I won 🥇 in 🏏"
#convert_emojis_to_word(text)

# %%
#Just to see if it works fine
convert_emojis_to_word(df['biography'][1])
# Out:
# 'globe_showing_Americas🧳fire1st_place_medalartist_palettewine_glasshot_beverage\n          🇻🇪  🇨🇴\nEMPRESARIO SOÑADOR\n@alexpintoarte\n@ileinktattoostudio\n@microcapillum'

# %%
df.biography
# Out:
# 0                                                      NaN
# 1        🌎🧳🔥🥇🎨🍷☕\n          🇻🇪  🇨🇴\nEMPRESARIO SOÑADOR\...
# 2                                                      NaN
# 3            Consultant Plastic and Reconstructive Surgeon
# 4                                                      NaN
#                                ...
# 44154    Consultant Plastic Surgeon\n▪️London, U.K. \n📩...
# 44155    Consultant Plastic Surgeon\n▪️London, U.K. \n📩...
# 44156    Consultant Plastic Surgeon\n▪️London, U.K. \n📩...
# 44157    Consultant Plastic Surgeon\n▪️London, U.K. \n📩...
# 44158                                                  NaN
# Name: biography, Length: 44159, dtype: object

# %%
#It takes 1h36 min to run. No need to compile again. The result is stored in a new dataset 'data_with_converted_emojis_bio.csv'
df.biography=df.biography.map(lambda x : convert_emojis_to_word(str(x)))

# %%
df.head()
# Out:
#   account caption profile_name profile_image_link  \
# 0     NaN     NaN          NaN                NaN
# 1     NaN     NaN          NaN                NaN
# 2     NaN     NaN          NaN                NaN
# 3     NaN     NaN          NaN                NaN
# 4     NaN     NaN          NaN                NaN
#
#                                            biography            id  \
# 0                                                nan           NaN
# 1  globe_showing_Americas🧳fire1st_place_medalarti...  3.654414e+09
# 2                                                nan           NaN
# 3      Consultant Plastic and Reconstructive Surgeon  1.366797e+09
# 4                                                nan           NaN
#
#    business_email           external_url  following  likes media_type  \
# 0             NaN                    NaN        NaN    NaN        NaN
# 1             NaN                    NaN     1105.0    NaN        NaN
# 2             NaN                    NaN        NaN    NaN        NaN
# 3             NaN  http://www.psauk.org/       57.0    NaN        NaN
# 4             NaN                    NaN        NaN    NaN        NaN
#
#    posts_count  followers  is_verified  datetime image_url  url  comments  \
# 0          NaN        NaN          NaN       NaN       NaN  NaN       NaN
# 1        515.0     1244.0          NaN       NaN       NaN  NaN       NaN
# 2          NaN        NaN          NaN       NaN       NaN  NaN       NaN
# 3          8.0       13.0          NaN       NaN       NaN  NaN       NaN
# 4          NaN        NaN          NaN       NaN       NaN  NaN       NaN
#
#   thumbnails location
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN

# %%
df.to_csv('data_with_converted_emojis_bio.csv', encoding='utf-8')

# %%
df=pd.read_csv('data_with_converted_emojis_bio.csv', encoding='utf-8')

# %%
df.caption=df.caption.map(lambda x : convert_emojis_to_word(str(x)))

# %%
df.to_csv('data_with_converted_emojis_cap.csv', encoding='utf-8')

# %%
df=pd.read_csv('data_with_converted_emojis_bio.csv', encoding='utf-8')

# %% [markdown]
# ##Creation of Hashtags

# %%
df["hashtags"] = df.caption.apply(lambda x: [x for x in str(x).split(" ") if x.startswith("#")])

# %% [markdown]
# ##Text Lower

# %%
df.apply(lambda x: x.astype(str).str.lower())
df
# Out:
#        Unnamed: 0           account  \
# 0               0               NaN
# 1               1               NaN
# 2               2               NaN
# 3               3               NaN
# 4               4               NaN
# ...           ...               ...
# 44154       44154  drdariushnikkhah
# 44155       44155  drdariushnikkhah
# 44156       44156  drdariushnikkhah
# 44157       44157  drdariushnikkhah
# 44158       44158  drdariushnikkhah
#
#                                                  caption  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  Finalising the 50 chapters of an exciting book...
# 44155  At Harefield heart ❤️ hospital - probably only...
# 44156  Great to be back at the first face to face sci...
# 44157  Before and after of a bilateral breast reducti...
# 44158  Local anaesthetic flexor tendon repair is a sa...
#
#                          profile_name  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 44154  Mr Dariush Nikkhah FRCS(Plast)
# 44155  Mr Dariush Nikkhah FRCS(Plast)
# 44156  Mr Dariush Nikkhah FRCS(Plast)
# 44157  Mr Dariush Nikkhah FRCS(Plast)
# 44158  Mr Dariush Nikkhah FRCS(Plast)
#
#                                       profile_image_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44155  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44156  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44157  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44158  https://scontent-lhr8-1.cdninstagram.com/v/t51...
#
#                                                biography            id  \
# 0                                                    NaN           NaN
# 1      globe_showing_Americas🧳fire1st_place_medalarti...  3.654414e+09
# 2                                                    NaN           NaN
# 3          Consultant Plastic and Reconstructive Surgeon  1.366797e+09
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44154  Consultant Plastic Surgeon\nblack_small_square...  2.648973e+18
# 44155  Consultant Plastic Surgeon\nblack_small_square...  2.647971e+18
# 44156  Consultant Plastic Surgeon\nblack_small_square...  2.659552e+18
# 44157  Consultant Plastic Surgeon\nblack_small_square...  2.646593e+18
# 44158                                                NaN           NaN
#
#        business_email                         external_url  following  ...  \
# 0                 NaN                                  NaN        NaN  ...
# 1                 NaN                                  NaN     1105.0  ...
# 2                 NaN                                  NaN        NaN  ...
# 3                 NaN                http://www.psauk.org/       57.0  ...
# 4                 NaN                                  NaN        NaN  ...
# ...               ...                                  ...        ...  ...
# 44154             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44155             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44156             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44157             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44158             NaN                                  NaN        NaN  ...
#
#        posts_count followers  is_verified      datetime  \
# 0              NaN       NaN          NaN           NaN
# 1            515.0    1244.0          NaN           NaN
# 2              NaN       NaN          NaN           NaN
# 3              8.0      13.0          NaN           NaN
# 4              NaN       NaN          NaN           NaN
# ...            ...       ...          ...           ...
# 44154        136.0    1124.0          NaN  1.630002e+12
# 44155        136.0    1124.0          NaN  1.629883e+12
# 44156        136.0    1124.0          NaN  1.631263e+12
# 44157        136.0    1124.0          NaN  1.629718e+12
# 44158          NaN       NaN          NaN           NaN
#
#                                                image_url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44155  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44156  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44157  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44158                                                NaN
#
#                                             url comments  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
# ...                                         ...      ...
# 44154  https://www.instagram.com/p/CTDCnYcqSBP/      6.0
# 44155  https://www.instagram.com/p/CS_e1ntq-Qo/      3.0
# 44156  https://www.instagram.com/p/CTooI4TK0sF/      0.0
# 44157  https://www.instagram.com/p/CS6lisWKX4k/      7.0
# 44158                                       NaN      NaN
#
#                                               thumbnails  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44155  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44156  [{"src":"https://scontent-lhr8-1.cdninstagram....
# 44157  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44158                                                NaN
#
#                      location  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 44154  London, United Kingdom
# 44155                     NaN
# 44156     Oxford, Oxfordshire
# 44157  London, United Kingdom
# 44158                     NaN
#
#                                                 hashtags
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 44154                                                 []
# 44155                                                 []
# 44156                                                 []
# 44157  [#plasticsurgery, #breastsurgery, #breastreduc...
# 44158  [#wideawakehandsurgery, #walant, #flexortendon...
#
# [44159 rows x 22 columns]

# %% [markdown]
# ##Remove punctuation

# %%
df["biography_wo_punc"] = df["biography"].str.replace('[{}]'.format(string.punctuation), '')
df["caption_wo_punc"] = df["caption"].str.replace('[{}]'.format(string.punctuation), '')
df["profile_wo_punc"] = df["profile_name"].str.replace('[{}]'.format(string.punctuation), '')
# df["tokens_wo_punc"] = df["tokens"].str.replace('[{}]'.format(string.punctuation), '')

df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
#        Unnamed: 0           account  \
# 0               0               NaN
# 1               1               NaN
# 2               2               NaN
# 3               3               NaN
# 4               4               NaN
# ...           ...               ...
# 44154       44154  drdariushnikkhah
# 44155       44155  drdariushnikkhah
# 44156       44156  drdariushnikkhah
# 44157       44157  drdariushnikkhah
# 44158       44158  drdariushnikkhah
#
#                                                  caption  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  Finalising the 50 chapters of an exciting book...
# 44155  At Harefield heart ❤️ hospital - probably only...
# 44156  Great to be back at the first face to face sci...
# 44157  Before and after of a bilateral breast reducti...
# 44158  Local anaesthetic flexor tendon repair is a sa...
#
#                          profile_name  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 44154  Mr Dariush Nikkhah FRCS(Plast)
# 44155  Mr Dariush Nikkhah FRCS(Plast)
# 44156  Mr Dariush Nikkhah FRCS(Plast)
# 44157  Mr Dariush Nikkhah FRCS(Plast)
# 44158  Mr Dariush Nikkhah FRCS(Plast)
#
#                                       profile_image_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44155  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44156  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44157  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44158  https://scontent-lhr8-1.cdninstagram.com/v/t51...
#
#                                                biography            id  \
# 0                                                    NaN           NaN
# 1      globe_showing_Americas🧳fire1st_place_medalarti...  3.654414e+09
# 2                                                    NaN           NaN
# 3          Consultant Plastic and Reconstructive Surgeon  1.366797e+09
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44154  Consultant Plastic Surgeon\nblack_small_square...  2.648973e+18
# 44155  Consultant Plastic Surgeon\nblack_small_square...  2.647971e+18
# 44156  Consultant Plastic Surgeon\nblack_small_square...  2.659552e+18
# 44157  Consultant Plastic Surgeon\nblack_small_square...  2.646593e+18
# 44158                                                NaN           NaN
#
#        business_email                         external_url  following  ...  \
# 0                 NaN                                  NaN        NaN  ...
# 1                 NaN                                  NaN     1105.0  ...
# 2                 NaN                                  NaN        NaN  ...
# 3                 NaN                http://www.psauk.org/       57.0  ...
# 4                 NaN                                  NaN        NaN  ...
# ...               ...                                  ...        ...  ...
# 44154             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44155             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44156             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44157             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44158             NaN                                  NaN        NaN  ...
#
#            datetime                                          image_url  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 44154  1.630002e+12  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44155  1.629883e+12  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44156  1.631263e+12  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44157  1.629718e+12  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44158           NaN                                                NaN
#
#                                             url  comments  \
# 0                                           NaN       NaN
# 1                                           NaN       NaN
# 2                                           NaN       NaN
# 3                                           NaN       NaN
# 4                                           NaN       NaN
# ...                                         ...       ...
# 44154  https://www.instagram.com/p/CTDCnYcqSBP/       6.0
# 44155  https://www.instagram.com/p/CS_e1ntq-Qo/       3.0
# 44156  https://www.instagram.com/p/CTooI4TK0sF/       0.0
# 44157  https://www.instagram.com/p/CS6lisWKX4k/       7.0
# 44158                                       NaN       NaN
#
#                                               thumbnails  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44155  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44156  [{"src":"https://scontent-lhr8-1.cdninstagram....
# 44157  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44158                                                NaN
#
#                      location  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 44154  London, United Kingdom
# 44155                     NaN
# 44156     Oxford, Oxfordshire
# 44157  London, United Kingdom
# 44158                     NaN
#
#                                                 hashtags  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 44154                                                 []
# 44155                                                 []
# 44156                                                 []
# 44157  [#plasticsurgery, #breastsurgery, #breastreduc...
# 44158  [#wideawakehandsurgery, #walant, #flexortendon...
#
#                                        biography_wo_punc  \
# 0                                                    NaN
# 1      globeshowingAmericas🧳fire1stplacemedalartistpa...
# 2                                                    NaN
# 3          Consultant Plastic and Reconstructive Surgeon
# 4                                                    NaN
# ...                                                  ...
# 44154  Consultant Plastic Surgeon\nblacksmallsquare️L...
# 44155  Consultant Plastic Surgeon\nblacksmallsquare️L...
# 44156  Consultant Plastic Surgeon\nblacksmallsquare️L...
# 44157  Consultant Plastic Surgeon\nblacksmallsquare️L...
# 44158                                                NaN
#
#                                          caption_wo_punc  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  Finalising the 50 chapters of an exciting book...
# 44155  At Harefield heart ❤️ hospital  probably only ...
# 44156  Great to be back at the first face to face sci...
# 44157  Before and after of a bilateral breast reducti...
# 44158  Local anaesthetic flexor tendon repair is a sa...
#
#                     profile_wo_punc
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 44154  Mr Dariush Nikkhah FRCSPlast
# 44155  Mr Dariush Nikkhah FRCSPlast
# 44156  Mr Dariush Nikkhah FRCSPlast
# 44157  Mr Dariush Nikkhah FRCSPlast
# 44158  Mr Dariush Nikkhah FRCSPlast
#
# [44159 rows x 25 columns]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df["biography_wo_stop"] = df["biography_wo_punc"].apply(lambda text: remove_stopwords(text))
df["caption_wo_stop"] = df["caption_wo_punc"].apply(lambda text: remove_stopwords(text))
df["profile_wo_stop"] = df["profile_wo_punc"].apply(lambda text: remove_stopwords(text))
# df["tokens_wo_stop"] = df["tokens_wo_punc"].apply(lambda text: remove_stopwords(text))

# %% [markdown]
# ##Removal of frequent words

# %%
from collections import Counter
cnt = Counter()
for text in df["biography_wo_stop"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)
# Out:
# [('London', 5395),
#  ('The', 4058),
#  ('heart', 3748),
#  ('Plastic', 3476),
#  ('Surgeon', 3373),
#  ('link', 3299),
#  ('hotel', 3072),
#  ('A', 3041),
#  ('Open', 3025),
#  ('roundpushpin', 2619)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
# def remove_freqwords(text):
#     """custom function to remove the frequent words"""
#     return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["biography_wo_stopfreq"] = df["biography_wo_stop"].apply(lambda text: remove_freqwords(text))
df["caption_wo_stopfreq"] = df["caption_wo_stop"].apply(lambda text: remove_freqwords(text))
df["profile_wo_stopfreq"] = df["profile_wo_stop"].apply(lambda text: remove_freqwords(text))
# df["tokens_wo_stopfreq"] = df["tokens_wo_stop"].apply(lambda text: remove_freqwords(text))

df.head()
# Out:
#    Unnamed: 0 account caption profile_name profile_image_link  \
# 0           0     NaN     NaN          NaN                NaN
# 1           1     NaN     NaN          NaN                NaN
# 2           2     NaN     NaN          NaN                NaN
# 3           3     NaN     NaN          NaN                NaN
# 4           4     NaN     NaN          NaN                NaN
#
#                                            biography            id  \
# 0                                                NaN           NaN
# 1  globe_showing_Americas🧳fire1st_place_medalarti...  3.654414e+09
# 2                                                NaN           NaN
# 3      Consultant Plastic and Reconstructive Surgeon  1.366797e+09
# 4                                                NaN           NaN
#
#    business_email           external_url  following  ...  hashtags  \
# 0             NaN                    NaN        NaN  ...        []
# 1             NaN                    NaN     1105.0  ...        []
# 2             NaN                    NaN        NaN  ...        []
# 3             NaN  http://www.psauk.org/       57.0  ...        []
# 4             NaN                    NaN        NaN  ...        []
#
#                                    biography_wo_punc  caption_wo_punc  \
# 0                                                NaN              NaN
# 1  globeshowingAmericas🧳fire1stplacemedalartistpa...              NaN
# 2                                                NaN              NaN
# 3      Consultant Plastic and Reconstructive Surgeon              NaN
# 4                                                NaN              NaN
#
#    profile_wo_punc                                  biography_wo_stop  \
# 0              NaN                                                nan
# 1              NaN  globeshowingAmericas🧳fire1stplacemedalartistpa...
# 2              NaN                                                nan
# 3              NaN          Consultant Plastic Reconstructive Surgeon
# 4              NaN                                                nan
#
#    caption_wo_stop profile_wo_stop  \
# 0              nan             nan
# 1              nan             nan
# 2              nan             nan
# 3              nan             nan
# 4              nan             nan
#
#                                biography_wo_stopfreq  caption_wo_stopfreq  \
# 0                                                nan                  nan
# 1  globeshowingAmericas🧳fire1stplacemedalartistpa...                  nan
# 2                                                nan                  nan
# 3                          Consultant Reconstructive                  nan
# 4                                                nan                  nan
#
#   profile_wo_stopfreq
# 0                 nan
# 1                 nan
# 2                 nan
# 3                 nan
# 4                 nan
#
# [5 rows x 31 columns]

# %% [markdown]
# ##removal of rare words

# %%
n_rare_words = 10
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])

# %%
df["biography_wo_stopfreqrare"] = df["biography_wo_stopfreq"].apply(lambda text: remove_rarewords(text))
df["caption_wo_stopfreqrare"] = df["caption_wo_stopfreq"].apply(lambda text: remove_rarewords(text))
df["profile_wo_stopfreqrare"] = df["profile_wo_stopfreq"].apply(lambda text: remove_rarewords(text))
# df["tokens_wo_stopfreqrare"] = df["tokens_wo_stopfreq"].apply(lambda text: remove_rarewords(text))

df.head()
# Out:
#    Unnamed: 0 account caption profile_name profile_image_link  \
# 0           0     NaN     NaN          NaN                NaN
# 1           1     NaN     NaN          NaN                NaN
# 2           2     NaN     NaN          NaN                NaN
# 3           3     NaN     NaN          NaN                NaN
# 4           4     NaN     NaN          NaN                NaN
#
#                                            biography            id  \
# 0                                                NaN           NaN
# 1  globe_showing_Americas🧳fire1st_place_medalarti...  3.654414e+09
# 2                                                NaN           NaN
# 3      Consultant Plastic and Reconstructive Surgeon  1.366797e+09
# 4                                                NaN           NaN
#
#    business_email           external_url  following  ...  profile_wo_punc  \
# 0             NaN                    NaN        NaN  ...              NaN
# 1             NaN                    NaN     1105.0  ...              NaN
# 2             NaN                    NaN        NaN  ...              NaN
# 3             NaN  http://www.psauk.org/       57.0  ...              NaN
# 4             NaN                    NaN        NaN  ...              NaN
#
#                                    biography_wo_stop  caption_wo_stop  \
# 0                                                nan              nan
# 1  globeshowingAmericas🧳fire1stplacemedalartistpa...              nan
# 2                                                nan              nan
# 3          Consultant Plastic Reconstructive Surgeon              nan
# 4                                                nan              nan
#
#    profile_wo_stop                              biography_wo_stopfreq  \
# 0              nan                                                nan
# 1              nan  globeshowingAmericas🧳fire1stplacemedalartistpa...
# 2              nan                                                nan
# 3              nan                          Consultant Reconstructive
# 4              nan                                                nan
#
#    caption_wo_stopfreq profile_wo_stopfreq  \
# 0                  nan                 nan
# 1                  nan                 nan
# 2                  nan                 nan
# 3                  nan                 nan
# 4                  nan                 nan
#
#                            biography_wo_stopfreqrare  caption_wo_stopfreqrare  \
# 0                                                nan                      nan
# 1  globeshowingAmericas🧳fire1stplacemedalartistpa...                      nan
# 2                                                nan                      nan
# 3                          Consultant Reconstructive                      nan
# 4                                                nan                      nan
#
#   profile_wo_stopfreqrare
# 0                     nan
# 1                     nan
# 2                     nan
# 3                     nan
# 4                     nan
#
# [5 rows x 34 columns]

# %% [markdown]
# ##Stemming

# %%
# from nltk.stem.porter import PorterStemmer

# stemmer = PorterStemmer()
# def stem_words(text):
#     return " ".join([stemmer.stem(word) for word in text.split()])

# %%
df["biography_stemmed"] = df["biography_wo_stopfreqrare"].apply(lambda text: stem_words(text))
df["caption_stemmed"] = df["caption_wo_stopfreqrare"].apply(lambda text: stem_words(text))
# df["profile_stemmed"] = df["profile_wo_punc"].str.apply(lambda text: stem_words(text))
# df["tokens_stemmed"] = df["tokens_wo_punc"].apply(lambda text: stem_words(text))

# %% [markdown]
# ##Lemmatization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# lemmatizer = WordNetLemmatizer()
# def lemmatize_words(text):
#     return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

df["biography_final"] = df["biography_stemmed"].apply(lambda text: lemmatize_words(text))
df["caption_final"] = df["caption_stemmed"].apply(lambda text: lemmatize_words(text))
df["profile_final"] = df["profile_wo_stopfreqrare"].apply(lambda text: lemmatize_words(text))
# df["tokens_final"] = df["tokens_stemmed"].apply(lambda text: lemmatize_words(text))

df.head()
# Out:
#    Unnamed: 0 account caption profile_name profile_image_link  \
# 0           0     NaN     NaN          NaN                NaN
# 1           1     NaN     NaN          NaN                NaN
# 2           2     NaN     NaN          NaN                NaN
# 3           3     NaN     NaN          NaN                NaN
# 4           4     NaN     NaN          NaN                NaN
#
#                                            biography            id  \
# 0                                                NaN           NaN
# 1  globe_showing_Americas🧳fire1st_place_medalarti...  3.654414e+09
# 2                                                NaN           NaN
# 3      Consultant Plastic and Reconstructive Surgeon  1.366797e+09
# 4                                                NaN           NaN
#
#    business_email           external_url  following  ...  caption_wo_stopfreq  \
# 0             NaN                    NaN        NaN  ...                  nan
# 1             NaN                    NaN     1105.0  ...                  nan
# 2             NaN                    NaN        NaN  ...                  nan
# 3             NaN  http://www.psauk.org/       57.0  ...                  nan
# 4             NaN                    NaN        NaN  ...                  nan
#
#   profile_wo_stopfreq                          biography_wo_stopfreqrare  \
# 0                 nan                                                nan
# 1                 nan  globeshowingAmericas🧳fire1stplacemedalartistpa...
# 2                 nan                                                nan
# 3                 nan                          Consultant Reconstructive
# 4                 nan                                                nan
#
#    caption_wo_stopfreqrare  profile_wo_stopfreqrare  \
# 0                      nan                      nan
# 1                      nan                      nan
# 2                      nan                      nan
# 3                      nan                      nan
# 4                      nan                      nan
#
#                                    biography_stemmed caption_stemmed  \
# 0                                                nan             nan
# 1  globeshowingamericas🧳fire1stplacemedalartistpa...             nan
# 2                                                nan             nan
# 3                                consult reconstruct             nan
# 4                                                nan             nan
#
#                                      biography_final  caption_final  \
# 0                                                nan            nan
# 1  globeshowingamericas🧳fire1stplacemedalartistpa...            nan
# 2                                                nan            nan
# 3                                consult reconstruct            nan
# 4                                                nan            nan
#
#   profile_final
# 0           nan
# 1           nan
# 2           nan
# 3           nan
# 4           nan
#
# [5 rows x 39 columns]

# %% [markdown]
# ##Removal of URLs

# %%
df['biography_final'] = df['biography_final'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])
df['caption_final'] = df['caption_final'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])
df
# Out:
#        Unnamed: 0           account  \
# 0               0               NaN
# 1               1               NaN
# 2               2               NaN
# 3               3               NaN
# 4               4               NaN
# ...           ...               ...
# 44154       44154  drdariushnikkhah
# 44155       44155  drdariushnikkhah
# 44156       44156  drdariushnikkhah
# 44157       44157  drdariushnikkhah
# 44158       44158  drdariushnikkhah
#
#                                                  caption  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  Finalising the 50 chapters of an exciting book...
# 44155  At Harefield heart ❤️ hospital - probably only...
# 44156  Great to be back at the first face to face sci...
# 44157  Before and after of a bilateral breast reducti...
# 44158  Local anaesthetic flexor tendon repair is a sa...
#
#                          profile_name  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 44154  Mr Dariush Nikkhah FRCS(Plast)
# 44155  Mr Dariush Nikkhah FRCS(Plast)
# 44156  Mr Dariush Nikkhah FRCS(Plast)
# 44157  Mr Dariush Nikkhah FRCS(Plast)
# 44158  Mr Dariush Nikkhah FRCS(Plast)
#
#                                       profile_image_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44155  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44156  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44157  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 44158  https://scontent-lhr8-1.cdninstagram.com/v/t51...
#
#                                                biography            id  \
# 0                                                    NaN           NaN
# 1      globe_showing_Americas🧳fire1st_place_medalarti...  3.654414e+09
# 2                                                    NaN           NaN
# 3          Consultant Plastic and Reconstructive Surgeon  1.366797e+09
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44154  Consultant Plastic Surgeon\nblack_small_square...  2.648973e+18
# 44155  Consultant Plastic Surgeon\nblack_small_square...  2.647971e+18
# 44156  Consultant Plastic Surgeon\nblack_small_square...  2.659552e+18
# 44157  Consultant Plastic Surgeon\nblack_small_square...  2.646593e+18
# 44158                                                NaN           NaN
#
#        business_email                         external_url  following  ...  \
# 0                 NaN                                  NaN        NaN  ...
# 1                 NaN                                  NaN     1105.0  ...
# 2                 NaN                                  NaN        NaN  ...
# 3                 NaN                http://www.psauk.org/       57.0  ...
# 4                 NaN                                  NaN        NaN  ...
# ...               ...                                  ...        ...  ...
# 44154             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44155             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44156             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44157             NaN  https://www.plasticreconsurg.co.uk/      299.0  ...
# 44158             NaN                                  NaN        NaN  ...
#
#                                      caption_wo_stopfreq  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 44154  Finalising 50 chapters exciting book due relea...
# 44155  At Harefield ❤️ hospital probably hospital I k...
# 44156  Great back first face face scientific meeting ...
# 44157  Before bilateral breast reduction procedure I ...
# 44158  Local anaesthetic flexor tendon repair safe ef...
#
#                 profile_wo_stopfreq  \
# 0                               nan
# 1                               nan
# 2                               nan
# 3                               nan
# 4                               nan
# ...                             ...
# 44154  Mr Dariush Nikkhah FRCSPlast
# 44155  Mr Dariush Nikkhah FRCSPlast
# 44156  Mr Dariush Nikkhah FRCSPlast
# 44157  Mr Dariush Nikkhah FRCSPlast
# 44158  Mr Dariush Nikkhah FRCSPlast
#
#                                biography_wo_stopfreqrare  \
# 0                                                    nan
# 1      globeshowingAmericas🧳fire1stplacemedalartistpa...
# 2                                                    nan
# 3                              Consultant Reconstructive
# 4                                                    nan
# ...                                                  ...
# 44154  Consultant blacksmallsquare️London UK envelope...
# 44155  Consultant blacksmallsquare️London UK envelope...
# 44156  Consultant blacksmallsquare️London UK envelope...
# 44157  Consultant blacksmallsquare️London UK envelope...
# 44158                                                nan
#
#                                  caption_wo_stopfreqrare  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 44154  Finalising 50 chapters exciting book due relea...
# 44155  At Harefield ❤️ hospital probably hospital I k...
# 44156  Great back first face face scientific meeting ...
# 44157  Before bilateral breast reduction procedure I ...
# 44158  Local anaesthetic flexor tendon repair safe ef...
#
#             profile_wo_stopfreqrare  \
# 0                               nan
# 1                               nan
# 2                               nan
# 3                               nan
# 4                               nan
# ...                             ...
# 44154  Mr Dariush Nikkhah FRCSPlast
# 44155  Mr Dariush Nikkhah FRCSPlast
# 44156  Mr Dariush Nikkhah FRCSPlast
# 44157  Mr Dariush Nikkhah FRCSPlast
# 44158  Mr Dariush Nikkhah FRCSPlast
#
#                                        biography_stemmed  \
# 0                                                    nan
# 1      globeshowingamericas🧳fire1stplacemedalartistpa...
# 2                                                    nan
# 3                                    consult reconstruct
# 4                                                    nan
# ...                                                  ...
# 44154  consult blacksmallsquare️london UK envelopewit...
# 44155  consult blacksmallsquare️london UK envelopewit...
# 44156  consult blacksmallsquare️london UK envelopewit...
# 44157  consult blacksmallsquare️london UK envelopewit...
# 44158                                                nan
#
#                                          caption_stemmed  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 44154  finalis 50 chapter excit book due releas year ...
# 44155  At harefield ❤️ hospit probabl hospit I know s...
# 44156  great back first face face scientif meet 2 yea...
# 44157  befor bilater breast reduct procedur I perform...
# 44158  local anaesthet flexor tendon repair safe effe...
#
#                                          biography_final  \
# 0                                                    nan
# 1      globeshowingamericas🧳fire1stplacemedalartistpa...
# 2                                                    nan
# 3                                    consult reconstruct
# 4                                                    nan
# ...                                                  ...
# 44154  consult blacksmallsquare️london UK envelopewit...
# 44155  consult blacksmallsquare️london UK envelopewit...
# 44156  consult blacksmallsquare️london UK envelopewit...
# 44157  consult blacksmallsquare️london UK envelopewit...
# 44158                                                nan
#
#                                            caption_final  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 44154  finalis 50 chapter excit book due releas year ...
# 44155  At harefield ❤️ hospit probabl hospit I know s...
# 44156  great back first face face scientif meet 2 yea...
# 44157  befor bilater breast reduct procedur I perform...
# 44158  local anaesthet flexor tendon repair safe effe...
#
#                       profile_final
# 0                               nan
# 1                               nan
# 2                               nan
# 3                               nan
# 4                               nan
# ...                             ...
# 44154  Mr Dariush Nikkhah FRCSPlast
# 44155  Mr Dariush Nikkhah FRCSPlast
# 44156  Mr Dariush Nikkhah FRCSPlast
# 44157  Mr Dariush Nikkhah FRCSPlast
# 44158  Mr Dariush Nikkhah FRCSPlast
#
# [44159 rows x 39 columns]

# %% [markdown]
# #Final dataframe

# %%
df_final=df.drop(['biography','caption', 'profile_name', 'biography_wo_punc',	'caption_wo_punc'	,'biography_wo_stop',	'caption_wo_stop',	'profile_wo_punc'	,'profile_wo_stop'	,'biography_wo_stopfreq',	'caption_wo_stopfreq'	,'profile_wo_stopfreq','biography_wo_stopfreqrare'	,'caption_wo_stopfreqrare',	'profile_wo_stopfreqrare'	,'biography_stemmed'	,'caption_stemmed'], axis=1)
df_final
# Out:
#        Unnamed: 0           account  \
# 0               0               NaN
# 1               1               NaN
# 2               2               NaN
# 3               3               NaN
# 4               4               NaN
# ...           ...               ...
# 44154       44154  drdariushnikkhah
# 44155       44155  drdariushnikkhah
# 44156       44156  drdariushnikkhah
# 44157       44157  drdariushnikkhah
# 44158       44158  drdariushnikkhah
#
#                                       profile_image_link            id  \
# 0                                                    NaN           NaN
# 1                                                    NaN  3.654414e+09
# 2                                                    NaN           NaN
# 3                                                    NaN  1.366797e+09
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44154  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.648973e+18
# 44155  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.647971e+18
# 44156  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.659552e+18
# 44157  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.646593e+18
# 44158  https://scontent-lhr8-1.cdninstagram.com/v/t51...           NaN
#
#        business_email                         external_url  following  likes  \
# 0                 NaN                                  NaN        NaN    NaN
# 1                 NaN                                  NaN     1105.0    NaN
# 2                 NaN                                  NaN        NaN    NaN
# 3                 NaN                http://www.psauk.org/       57.0    NaN
# 4                 NaN                                  NaN        NaN    NaN
# ...               ...                                  ...        ...    ...
# 44154             NaN  https://www.plasticreconsurg.co.uk/      299.0  137.0
# 44155             NaN  https://www.plasticreconsurg.co.uk/      299.0   83.0
# 44156             NaN  https://www.plasticreconsurg.co.uk/      299.0   75.0
# 44157             NaN  https://www.plasticreconsurg.co.uk/      299.0   77.0
# 44158             NaN                                  NaN        NaN    NaN
#
#       media_type  posts_count  ...      datetime  \
# 0            NaN          NaN  ...           NaN
# 1            NaN        515.0  ...           NaN
# 2            NaN          NaN  ...           NaN
# 3            NaN          8.0  ...           NaN
# 4            NaN          NaN  ...           NaN
# ...          ...          ...  ...           ...
# 44154      Image        136.0  ...  1.630002e+12
# 44155      Image        136.0  ...  1.629883e+12
# 44156   Carousel        136.0  ...  1.631263e+12
# 44157      Image        136.0  ...  1.629718e+12
# 44158        NaN          NaN  ...           NaN
#
#                                                image_url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44155  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44156  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44157  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44158                                                NaN
#
#                                             url comments  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
# ...                                         ...      ...
# 44154  https://www.instagram.com/p/CTDCnYcqSBP/      6.0
# 44155  https://www.instagram.com/p/CS_e1ntq-Qo/      3.0
# 44156  https://www.instagram.com/p/CTooI4TK0sF/      0.0
# 44157  https://www.instagram.com/p/CS6lisWKX4k/      7.0
# 44158                                       NaN      NaN
#
#                                               thumbnails  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44155  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44156  [{"src":"https://scontent-lhr8-1.cdninstagram....
# 44157  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44158                                                NaN
#
#                      location  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 44154  London, United Kingdom
# 44155                     NaN
# 44156     Oxford, Oxfordshire
# 44157  London, United Kingdom
# 44158                     NaN
#
#                                                 hashtags  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 44154                                                 []
# 44155                                                 []
# 44156                                                 []
# 44157  [#plasticsurgery, #breastsurgery, #breastreduc...
# 44158  [#wideawakehandsurgery, #walant, #flexortendon...
#
#                                          biography_final  \
# 0                                                    nan
# 1      globeshowingamericas🧳fire1stplacemedalartistpa...
# 2                                                    nan
# 3                                    consult reconstruct
# 4                                                    nan
# ...                                                  ...
# 44154  consult blacksmallsquare️london UK envelopewit...
# 44155  consult blacksmallsquare️london UK envelopewit...
# 44156  consult blacksmallsquare️london UK envelopewit...
# 44157  consult blacksmallsquare️london UK envelopewit...
# 44158                                                nan
#
#                                            caption_final  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 44154  finalis 50 chapter excit book due releas year ...
# 44155  At harefield ❤️ hospit probabl hospit I know s...
# 44156  great back first face face scientif meet 2 yea...
# 44157  befor bilater breast reduct procedur I perform...
# 44158  local anaesthet flexor tendon repair safe effe...
#
#                       profile_final
# 0                               nan
# 1                               nan
# 2                               nan
# 3                               nan
# 4                               nan
# ...                             ...
# 44154  Mr Dariush Nikkhah FRCSPlast
# 44155  Mr Dariush Nikkhah FRCSPlast
# 44156  Mr Dariush Nikkhah FRCSPlast
# 44157  Mr Dariush Nikkhah FRCSPlast
# 44158  Mr Dariush Nikkhah FRCSPlast
#
# [44159 rows x 22 columns]

# %%
df_final
# Out:
#        Unnamed: 0           account  \
# 0               0               NaN
# 1               1               NaN
# 2               2               NaN
# 3               3               NaN
# 4               4               NaN
# ...           ...               ...
# 44154       44154  drdariushnikkhah
# 44155       44155  drdariushnikkhah
# 44156       44156  drdariushnikkhah
# 44157       44157  drdariushnikkhah
# 44158       44158  drdariushnikkhah
#
#                                       profile_image_link            id  \
# 0                                                    NaN           NaN
# 1                                                    NaN  3.654414e+09
# 2                                                    NaN           NaN
# 3                                                    NaN  1.366797e+09
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44154  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.648973e+18
# 44155  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.647971e+18
# 44156  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.659552e+18
# 44157  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.646593e+18
# 44158  https://scontent-lhr8-1.cdninstagram.com/v/t51...           NaN
#
#        business_email                         external_url  following  likes  \
# 0                 NaN                                  NaN        NaN    NaN
# 1                 NaN                                  NaN     1105.0    NaN
# 2                 NaN                                  NaN        NaN    NaN
# 3                 NaN                http://www.psauk.org/       57.0    NaN
# 4                 NaN                                  NaN        NaN    NaN
# ...               ...                                  ...        ...    ...
# 44154             NaN  https://www.plasticreconsurg.co.uk/      299.0  137.0
# 44155             NaN  https://www.plasticreconsurg.co.uk/      299.0   83.0
# 44156             NaN  https://www.plasticreconsurg.co.uk/      299.0   75.0
# 44157             NaN  https://www.plasticreconsurg.co.uk/      299.0   77.0
# 44158             NaN                                  NaN        NaN    NaN
#
#       media_type  posts_count  ...      datetime  \
# 0            NaN          NaN  ...           NaN
# 1            NaN        515.0  ...           NaN
# 2            NaN          NaN  ...           NaN
# 3            NaN          8.0  ...           NaN
# 4            NaN          NaN  ...           NaN
# ...          ...          ...  ...           ...
# 44154      Image        136.0  ...  1.630002e+12
# 44155      Image        136.0  ...  1.629883e+12
# 44156   Carousel        136.0  ...  1.631263e+12
# 44157      Image        136.0  ...  1.629718e+12
# 44158        NaN          NaN  ...           NaN
#
#                                                image_url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44155  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44156  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44157  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44158                                                NaN
#
#                                             url comments  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
# ...                                         ...      ...
# 44154  https://www.instagram.com/p/CTDCnYcqSBP/      6.0
# 44155  https://www.instagram.com/p/CS_e1ntq-Qo/      3.0
# 44156  https://www.instagram.com/p/CTooI4TK0sF/      0.0
# 44157  https://www.instagram.com/p/CS6lisWKX4k/      7.0
# 44158                                       NaN      NaN
#
#                                               thumbnails  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44155  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44156  [{"src":"https://scontent-lhr8-1.cdninstagram....
# 44157  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44158                                                NaN
#
#                      location  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 44154  London, United Kingdom
# 44155                     NaN
# 44156     Oxford, Oxfordshire
# 44157  London, United Kingdom
# 44158                     NaN
#
#                                                 hashtags  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 44154                                                 []
# 44155                                                 []
# 44156                                                 []
# 44157  [#plasticsurgery, #breastsurgery, #breastreduc...
# 44158  [#wideawakehandsurgery, #walant, #flexortendon...
#
#                                          biography_final  \
# 0                                                    nan
# 1      globeshowingamericas🧳fire1stplacemedalartistpa...
# 2                                                    nan
# 3                                    consult reconstruct
# 4                                                    nan
# ...                                                  ...
# 44154  consult blacksmallsquare️london UK envelopewit...
# 44155  consult blacksmallsquare️london UK envelopewit...
# 44156  consult blacksmallsquare️london UK envelopewit...
# 44157  consult blacksmallsquare️london UK envelopewit...
# 44158                                                nan
#
#                                            caption_final  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 44154  finalis 50 chapter excit book due releas year ...
# 44155  At harefield ❤️ hospit probabl hospit I know s...
# 44156  great back first face face scientif meet 2 yea...
# 44157  befor bilater breast reduct procedur I perform...
# 44158  local anaesthet flexor tendon repair safe effe...
#
#                       profile_final
# 0                               nan
# 1                               nan
# 2                               nan
# 3                               nan
# 4                               nan
# ...                             ...
# 44154  Mr Dariush Nikkhah FRCSPlast
# 44155  Mr Dariush Nikkhah FRCSPlast
# 44156  Mr Dariush Nikkhah FRCSPlast
# 44157  Mr Dariush Nikkhah FRCSPlast
# 44158  Mr Dariush Nikkhah FRCSPlast
#
# [44159 rows x 22 columns]

# %%
df_final.drop(['account'], axis=1, inplace=True)
df_final.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# old_names = [ 'input_account', 'biography_final', 'caption_final', 'profile_final'] 
# new_names = {'account', 'biography', 'caption', 'profile'}
# df_final.columns=new_names


df = df_final.rename(columns={'input_account': 'account','biography_final':'biography','caption_final':'caption','profile_final':'profile'})

# %%
df
# Out:
#                                       profile_image_link            id  \
# 0                                                    NaN           NaN
# 1                                                    NaN  3.654414e+09
# 2                                                    NaN           NaN
# 3                                                    NaN  1.366797e+09
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44154  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.648973e+18
# 44155  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.647971e+18
# 44156  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.659552e+18
# 44157  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2.646593e+18
# 44158  https://scontent-lhr8-1.cdninstagram.com/v/t51...           NaN
#
#        business_email                         external_url  following  likes  \
# 0                 NaN                                  NaN        NaN    NaN
# 1                 NaN                                  NaN     1105.0    NaN
# 2                 NaN                                  NaN        NaN    NaN
# 3                 NaN                http://www.psauk.org/       57.0    NaN
# 4                 NaN                                  NaN        NaN    NaN
# ...               ...                                  ...        ...    ...
# 44154             NaN  https://www.plasticreconsurg.co.uk/      299.0  137.0
# 44155             NaN  https://www.plasticreconsurg.co.uk/      299.0   83.0
# 44156             NaN  https://www.plasticreconsurg.co.uk/      299.0   75.0
# 44157             NaN  https://www.plasticreconsurg.co.uk/      299.0   77.0
# 44158             NaN                                  NaN        NaN    NaN
#
#       media_type  posts_count  followers  is_verified      datetime  \
# 0            NaN          NaN        NaN          NaN           NaN
# 1            NaN        515.0     1244.0          NaN           NaN
# 2            NaN          NaN        NaN          NaN           NaN
# 3            NaN          8.0       13.0          NaN           NaN
# 4            NaN          NaN        NaN          NaN           NaN
# ...          ...          ...        ...          ...           ...
# 44154      Image        136.0     1124.0          NaN  1.630002e+12
# 44155      Image        136.0     1124.0          NaN  1.629883e+12
# 44156   Carousel        136.0     1124.0          NaN  1.631263e+12
# 44157      Image        136.0     1124.0          NaN  1.629718e+12
# 44158        NaN          NaN        NaN          NaN           NaN
#
#                                                image_url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44155  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44156  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44157  j_kzvc99wm2q4pjru5kn.c8774cb5509196a5a43b8ebc2...
# 44158                                                NaN
#
#                                             url  comments  \
# 0                                           NaN       NaN
# 1                                           NaN       NaN
# 2                                           NaN       NaN
# 3                                           NaN       NaN
# 4                                           NaN       NaN
# ...                                         ...       ...
# 44154  https://www.instagram.com/p/CTDCnYcqSBP/       6.0
# 44155  https://www.instagram.com/p/CS_e1ntq-Qo/       3.0
# 44156  https://www.instagram.com/p/CTooI4TK0sF/       0.0
# 44157  https://www.instagram.com/p/CS6lisWKX4k/       7.0
# 44158                                       NaN       NaN
#
#                                               thumbnails  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44154  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44155  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44156  [{"src":"https://scontent-lhr8-1.cdninstagram....
# 44157  [{"src":"https://scontent-lhr8-2.cdninstagram....
# 44158                                                NaN
#
#                      location  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 44154  London, United Kingdom
# 44155                     NaN
# 44156     Oxford, Oxfordshire
# 44157  London, United Kingdom
# 44158                     NaN
#
#                                                 hashtags  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 44154                                                 []
# 44155                                                 []
# 44156                                                 []
# 44157  [#plasticsurgery, #breastsurgery, #breastreduc...
# 44158  [#wideawakehandsurgery, #walant, #flexortendon...
#
#                                                biography  \
# 0                                                    nan
# 1      globeshowingamericas🧳fire1stplacemedalartistpa...
# 2                                                    nan
# 3                                    consult reconstruct
# 4                                                    nan
# ...                                                  ...
# 44154  consult blacksmallsquare️london UK envelopewit...
# 44155  consult blacksmallsquare️london UK envelopewit...
# 44156  consult blacksmallsquare️london UK envelopewit...
# 44157  consult blacksmallsquare️london UK envelopewit...
# 44158                                                nan
#
#                                                  caption  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 44154  finalis 50 chapter excit book due releas year ...
# 44155  At harefield ❤️ hospit probabl hospit I know s...
# 44156  great back first face face scientif meet 2 yea...
# 44157  befor bilater breast reduct procedur I perform...
# 44158  local anaesthet flexor tendon repair safe effe...
#
#                             profile
# 0                               nan
# 1                               nan
# 2                               nan
# 3                               nan
# 4                               nan
# ...                             ...
# 44154  Mr Dariush Nikkhah FRCSPlast
# 44155  Mr Dariush Nikkhah FRCSPlast
# 44156  Mr Dariush Nikkhah FRCSPlast
# 44157  Mr Dariush Nikkhah FRCSPlast
# 44158  Mr Dariush Nikkhah FRCSPlast
#
# [44159 rows x 20 columns]

# %%
df.to_csv('after_preprocessing.csv', encoding='utf-8')
